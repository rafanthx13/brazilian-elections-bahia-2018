# %% [markdown]
# # Eunapolis Principais Preços
#
# Não há API e o site é protegido contra Robos. Então, a melhor forma é buscar os dados, clicar F12, salvar como arquivo JSON; e salvar os dados.

# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# # Snippets

# %%
def to_df_from_list_of_objs_sorted(list_of_obj):
    """
        Converte de:
    [{'id': 5, 'nome': 'rafael'},  {'id': 6, 'nome': 'marta'}]
        Para DataFrame
    OBS: Esse processo é mais complxo pois tem que ser feito
    """
    variables = list_of_obj[0].keys()

    def aux_obj_to_list_sorted(obj, features):
        alist = []
        for feat in features:
            alist.append(obj[feat])
        return alist

    return pd.DataFrame(
                list( map( lambda x: aux_obj_to_list_sorted(x, variables), list_of_obj)),
                columns = variables)

# %% [markdown]
# # Procedure

# %% [markdown]
# ## Read JSON

# %%
def return_df_from_json_file(json_file, produto):
    json_data = json.load(open(json_file))
    estabelecimentos = [
        'RONDELLI COMERCIO E TRANSPORTE LTDA',
        'CAMBUI SUPERMERCADOS',
        'SACOLA CHEIA',
        'MINEIRAO ATACAREJO',
        'O ATACADAO',
        'SUPERMERCADO CARDOSO',
    ]
    date_query = json_data['dataConsulta']
    list_objs = []
    for el in json_data['resultado']:
        if(el['estabelecimento']['nomeEstabelecimento'] in estabelecimentos):
            adict = {}
            adict['produto'] = produto
            adict['produto_nome'] = el['produto']['descricao']
            adict['date_query'] = date_query
            adict['estabelecimento'] = el['estabelecimento']['nomeEstabelecimento']
            adict['rua'] = el['estabelecimento']['endLogradouro']+ ' - '+el['estabelecimento']['bairro']
            adict['preco'] = el['produto']['precoUnitario']
            list_objs.append(adict)
    # Formating
    temp_df =  to_df_from_list_of_objs_sorted(list_objs)
    temp_df['date_query'] = pd.to_datetime(temp_df["date_query"])
    temp_df['date_formated'] = temp_df["date_query"].dt.strftime('%d/%m/%Y %H:%M')
    temp_df['estabelecimento'] = temp_df['estabelecimento'].replace({
        'RONDELLI COMERCIO E TRANSPORTE LTDA': 'RONDELLI',
        'CAMBUI SUPERMERCADOS': 'CAMBUI',
    })
    return temp_df

# %%
json_data = json.load(open('chipa.json'))
json_data
# Out:
# {'codigo': 80,
#  'dataConsulta': '2022-05-03 21:35:21-00:00',
#  'pagina': 1,
#  'totalRegistros': 5,
#  'totalPaginas': 1,
#  'registrosporPagina': 25,
#  'registrosdaPagina': 5,
#  'dias': 72,
#  'categorias': [{'codigo': 6, 'descricao': 'OUTROS ALIMENTOS'},
#   {'codigo': 5, 'descricao': 'BISCOITO'}],
#  'centro': {'latitude': -16.3774464, 'longitude': -39.5640832, 'raio': 15},
#  'intervaloPreco': {'min': 2, 'max': 49},
#  'resultado': [{'produto': {'score': None,
#     'codProduto': '2708501600010946',
#     'tipoNFe': 65,
#     'gtin': None,
#     'anp': None,
#     'ncm': 19059090,
#     'cod_nfce': '4942026476',
#     'ncmGrupo': 'OUTROS ALIMENTOS',
#     'descricao': 'CHIPA QUEIJO',
#     'precoUnitario': 2,
#     'precoLiquido': 2,
#     'precoBruto': 2,
#     'desconto': None,
#     'unidade': 'UN',
#     'data': '2022-05-03 18:36:43-00:00',
#     'intervalo': 'hÃ¡ 2 hora(s), 58 minuto(s) e 38 segundo(s)',
#     'timeSpan': 10718,
#     'foto': 'https://api.precodahora.sefaz.ba.gov.br/v1/images/default'},
#    'estabelecimento': {'nomeEstabelecimento': 'PANIFICADORA E LANCHONETE SABOR REAL',
#     'endLogradouro': 'SANTOS DUMONT',
#     'endNumero': '706',
#     'cep': '45820011',
#     'bairro': 'CENTRO',
#     'codMunicipio': 2910727,
#     'municipio': 'EUNAPOLIS',
#     'uf': 'BA',
#     'cnpj': 27085016000109,
#     'telefone': None,
#     'latitude': -16.3728,
#     'longitude': -39.584791,
#     'tentativa': 1,
#     'distancia': 2.2688}},
#   {'produto': {'score': None,
#     'codProduto': '1993183000318689980',
#     'tipoNFe': 65,
#     'gtin': None,
#     'anp': None,
#     'ncm': 19053100,
#     'cod_nfce': '4942815251',
#     'ncmGrupo': 'BISCOITO',
#     'descricao': 'CHIPA KG PAD. RONDEL',
#     'precoUnitario': 28.9,
#     'precoLiquido': 28.9,
#     'precoBruto': 28.9,
#     'desconto': None,
#     'unidade': 'KG',
#     'data': '2022-05-03 20:52:19-00:00',
#     'intervalo': 'hÃ¡ 43 minuto(s) e 2 segundo(s)',
#     'timeSpan': 2582,
#     'foto': 'https://api.precodahora.sefaz.ba.gov.br/v1/images/default'},
#    'estabelecimento': {'nomeEstabelecimento': 'SUPERMERCADOS RONDELLI',
#     'endLogradouro': 'DO PEQUI',
#     'endNumero': '138',
#     'cep': '45820000',
#     'bairro': 'PIQUI',
#     'codMunicipio': 2910727,
#     'municipio': 'EUNAPOLIS',
#     'uf': 'BA',
#     'cnpj': 1993183000318,
#     'telefone': '7332811049',
#     'latitude': -16.3716929,
#     'longitude': -39.578354,
#     'tentativa': 1,
#     'distancia': 1.6514}},
#   {'produto': {'score': None,
#     'codProduto': '6353864001811689980',
#     'tipoNFe': 65,
#     'gtin': None,
#     'anp': None,
#     'ncm': 19053100,
#     'cod_nfce': '4942595937',
#     'ncmGrupo': 'BISCOITO',
#     'descricao': 'CHIPA KG PAD. RONDEL',
#     'precoUnitario': 28.9,
#     'precoLiquido': 28.9,
#     'precoBruto': 28.9,
#     'desconto': None,
#     'unidade': 'KG',
#     'data': '2022-05-03 20:18:13-00:00',
#     'intervalo': 'hÃ¡ 1 hora(s), 17 minuto(s) e 8 segundo(s)',
#     'timeSpan': 4628,
#     'foto': 'https://api.precodahora.sefaz.ba.gov.br/v1/images/default'},
#    'estabelecimento': {'nomeEstabelecimento': 'RONDELLI COMERCIO E TRANSPORTE LTDA',
#     'endLogradouro': 'SANTOS DUMONT',
#     'endNumero': '998',
#     'cep': '45820082',
#     'bairro': 'CENTRO',
#     'codMunicipio': 2910727,
#     'municipio': 'EUNAPOLIS',
#     'uf': 'BA',
#     'cnpj': 6353864001811,
#     'telefone': '7332815564',
#     'latitude': -16.3730516,
#     'longitude': -39.5878136,
#     'tentativa': 1,
#     'distancia': 2.5784}},
#   {'produto': {'score': None,
#     'codProduto': '6353864000840689980',
#     'tipoNFe': 65,
#     'gtin': None,
#     'anp': None,
#     'ncm': 19053100,
#     'cod_nfce': '4942328716',
#     'ncmGrupo': 'BISCOITO',
#     'descricao': 'CHIPA KG PAD. RONDEL',
#     'precoUnitario': 28.9,
#     'precoLiquido': 28.9,
#     'precoBruto': 28.9,
#     'desconto': None,
#     'unidade': 'KG',
#     'data': '2022-05-03 19:33:40-00:00',
#     'intervalo': 'hÃ¡ 2 hora(s), 1 minuto(s) e 41 segundo(s)',
#     'timeSpan': 7301,
#     'foto': 'https://api.precodahora.sefaz.ba.gov.br/v1/images/default'},
#    'estabelecimento': {'nomeEstabelecimento': 'RONDELLI COMERCIO E TRANSPORTE LTDA',
#     'endLogradouro': 'DOUTOR PAULO SOUTO',
#     'endNumero': '654',
#     'cep': '45821066',
#     'bairro': 'DOUTOR GUSMAO',
#     'codMunicipio': 2910727,
#     'municipio': 'EUNAPOLIS',
#     'uf': 'BA',
#     'cnpj': 6353864000840,
#     'telefone': None,
#     'latitude': -16.3683516,
#     'longitude': -39.5859778,
#     'tentativa': 1,
#     'distancia': 2.5454}},
#   {'produto': {'score': None,
#     'codProduto': '5846287000512626503',
#     'tipoNFe': 65,
#     'gtin': None,
#     'anp': None,
#     'ncm': 19012000,
#     'cod_nfce': '4942588368',
#     'ncmGrupo': 'OUTROS ALIMENTOS',
#     'descricao': 'CHIPA TRADICIONAL KG',
#     'precoUnitario': 49,
#     'precoLiquido': 49,
#     'precoBruto': 49,
#     'desconto': None,
#     'unidade': 'KG',
#     'data': '2022-05-03 20:17:03-00:00',
#     'intervalo': 'hÃ¡ 1 hora(s), 18 minuto(s) e 18 segundo(s)',
#     'timeSpan': 4698,
#     'foto': 'https://api.precodahora.sefaz.ba.gov.br/v1/images/default'},
#    'estabelecimento': {'nomeEstabelecimento': 'CAMBUI SUPERMERCADOS',
#     'endLogradouro': 'DEMETRIO COUTO GUERRIERI',
#     'endNumero': '22',
#     'cep': '45820095',
#     'bairro': 'CENTRO',
#     'codMunicipio': 2910727,
#     'municipio': 'EUNAPOLIS',
#     'uf': 'BA',
#     'cnpj': 5846287000512,
#     'telefone': None,
#     'latitude': -16.376199,
#     'longitude': -39.586477,
#     'tentativa': 9,
#     'distancia': 2.3931}}],
#  'tempoResposta': 0.013769865036010742}

# %% [markdown]
# ## get data from JSON

# %%
estabelecimentos = [
    'RONDELLI COMERCIO E TRANSPORTE LTDA',
    'CAMBUI SUPERMERCADOS',
    'SACOLA CHEIA',
    'MINEIRAO ATACAREJO',
    'O ATACADAO',
    'SUPERMERCADO CARDOSO',
]
produto = 'Chipa Kg'
date_query = json_data['dataConsulta']
list_objs = []
for el in json_data['resultado']:
    if(el['estabelecimento']['nomeEstabelecimento'] in estabelecimentos):
        adict = {}
        adict['produto'] = produto
        adict["unidade"] = el['produto']['unidade']
        adict['date_query'] = date_query
        adict['estabelecimento'] = el['estabelecimento']['nomeEstabelecimento']
        adict['rua'] = el['estabelecimento']['endLogradouro']+ ' - '+el['estabelecimento']['bairro']
        adict['date_query'] = pd.to_datetime(adf["date_query"])
        adict['date_formated'] = adf["date_query"].dt.strftime('%d/%m/%Y %H:%M')
        adict['preco'] = el['produto']['precoUnitario']
        
        list_objs.append(adict)

# %% [markdown]
# ## Processing Data

# %%
list_objs
# Out:
# [{'produto': 'Chipa Kg',
#   'date_query': '2022-05-03 21:35:21-00:00',
#   'estabelecimento': 'RONDELLI COMERCIO E TRANSPORTE LTDA',
#   'rua': 'SANTOS DUMONT - CENTRO',
#   'preco': 28.9},
#  {'produto': 'Chipa Kg',
#   'date_query': '2022-05-03 21:35:21-00:00',
#   'estabelecimento': 'RONDELLI COMERCIO E TRANSPORTE LTDA',
#   'rua': 'DOUTOR PAULO SOUTO - DOUTOR GUSMAO',
#   'preco': 28.9},
#  {'produto': 'Chipa Kg',
#   'date_query': '2022-05-03 21:35:21-00:00',
#   'estabelecimento': 'CAMBUI SUPERMERCADOS',
#   'rua': 'DEMETRIO COUTO GUERRIERI - CENTRO',
#   'preco': 49}]

# %%
adf = to_df_from_list_of_objs_sorted(list_objs)

# %%
adf['date_query'] = pd.to_datetime(adf["date_query"])
adf['date_formated'] = adf["date_query"].dt.strftime('%d/%m/%Y %H:%M')
adf
# Out:
#     produto          date_query                      estabelecimento  \
# 0  Chipa Kg 2022-03-05 21:35:00  RONDELLI COMERCIO E TRANSPORTE LTDA
# 1  Chipa Kg 2022-03-05 21:35:00  RONDELLI COMERCIO E TRANSPORTE LTDA
# 2  Chipa Kg 2022-03-05 21:35:00                 CAMBUI SUPERMERCADOS
#
#                                   rua  preco     date_formated
# 0              SANTOS DUMONT - CENTRO   28.9  05/03/2022 21:35
# 1  DOUTOR PAULO SOUTO - DOUTOR GUSMAO   28.9  05/03/2022 21:35
# 2   DEMETRIO COUTO GUERRIERI - CENTRO   49.0  05/03/2022 21:35

# %%
adf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   produto          3 non-null      object
#  1   date_query       3 non-null      datetime64[ns]
#  2   estabelecimento  3 non-null      object
#  3   rua              3 non-null      object
#  4   preco            3 non-null      float64
#  5   date_formated    3 non-null      object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 272.0+ bytes

# %% [markdown]
# ## Cebola
#
# Buscar por 'CEBOLA BRANCA KG'

# %%
return_df_from_json_file('cebola.json', 'Cebola Branca')
# Out:
#          produto                date_query       estabelecimento  \
# 0  Cebola Branca 2022-05-03 22:37:12+00:00          SACOLA CHEIA
# 1  Cebola Branca 2022-05-03 22:37:12+00:00  SUPERMERCADO CARDOSO
# 2  Cebola Branca 2022-05-03 22:37:12+00:00  SUPERMERCADO CARDOSO
# 3  Cebola Branca 2022-05-03 22:37:12+00:00              RONDELLI
# 4  Cebola Branca 2022-05-03 22:37:12+00:00              RONDELLI
# 5  Cebola Branca 2022-05-03 22:37:12+00:00              RONDELLI
# 6  Cebola Branca 2022-05-03 22:37:12+00:00                CAMBUI
#
#                                             rua  preco     date_formated
# 0                        SANTOS DUMONT - CENTRO   3.98  03/05/2022 22:37
# 1                            BELA VISTA - PEQUI   5.99  03/05/2022 22:37
# 2                        NOVA VISTA - ROSA NETO   5.99  03/05/2022 22:37
# 3            DOUTOR PAULO SOUTO - DOUTOR GUSMAO   6.95  03/05/2022 22:37
# 4  ANTONIO CARLOS MAGALHAES - ENCANTO DAS AGUAS   6.95  03/05/2022 22:37
# 5                        SANTOS DUMONT - CENTRO   6.95  03/05/2022 22:37
# 6             DEMETRIO COUTO GUERRIERI - CENTRO   6.99  03/05/2022 22:37

# %%
return_df_from_json_file('tomate.json', 'Tomate')
# Out:
#   produto         produto_nome                date_query estabelecimento  \
# 0  Tomate     TOMATE BOCA 7 KG 2022-05-03 22:55:11+00:00    SACOLA CHEIA
